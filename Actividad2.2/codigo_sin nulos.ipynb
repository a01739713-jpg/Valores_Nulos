# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Análisis_de_piso.xlsx')
df.head()
# Out:
#        Unnamed: 0 Leads Piso 2024 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0             NaN             459         27         95        110         65
# 1         Asesor              feb        mar        abr        may        jun
# 2         ABIGAIL              23        NaN        NaN        NaN        NaN
# 3   ALAN GONZALES               1        NaN        NaN        NaN        NaN
# 4  ALICIA LEDESMA             NaN        NaN          1        NaN        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...    Unnamed: 41  \
# 0        107         88         59         40  ...  RAKING VENTAS
# 1        jul        ago        sep        oct  ...            NaN
# 2        NaN        NaN        NaN        NaN  ...             23
# 3        NaN        NaN                   NaN  ...              6
# 4        NaN        NaN        NaN        NaN  ...              0
#
#             Unnamed: 42               979               811     Unnamed: 45  \
# ...

# %%
df_sinnulos = df.isnull().sum()
df_sinnulos
# Out:
# Unnamed: 0                                1
# Leads Piso 2024                          19
# Unnamed: 2                               31
# Unnamed: 3                               23
# Unnamed: 4                               28
# Unnamed: 5                               30
# Unnamed: 6                               29
# Unnamed: 7                               30
# Unnamed: 8                               27
# Unnamed: 9                               31
# Unnamed: 10                              25
# Unnamed: 11                              31
# Leads Piso 2025                          30
# Unnamed: 13                              30
# Unnamed: 14                              33
# Unnamed: 15                              31
# Total                                     0
# Total Ajustado                            0
# Raking                                    2
# Raking ajustado                           2
# Ventas Piso 2024                          0
# ...

# %%
#Eliminar primera fila o filas innecesarias
df_sinnulos= pd.read_excel('Análisis_de_piso.xlsx', skiprows=1)
df_sinnulos
# Out:
#                       Unnamed: 0  459   27   95  110   65  107   88   59   40  \
# 0                        Asesor   feb  mar  abr  may  jun  jul  ago  sep  oct
# 1                        ABIGAIL   23  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2                  ALAN GONZALES    1  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 3                 ALICIA LEDESMA  NaN  NaN    1  NaN  NaN  NaN  NaN  NaN  NaN
# 4                 AURELIO FELIPE  NaN  NaN  NaN  NaN  NaN  NaN  NaN    1    6
# 5           CARLOS ALBERTO NIETO  NaN  NaN  NaN    2  NaN  NaN    2    8    4
# 6                  CARLOS TEXIS   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    1
# 7          CARLOS MANUEL CARMONA   18   10   27   34   11    3  NaN  NaN  NaN
# 8                        CINTYA   NaN  NaN  NaN  NaN    1  NaN  NaN  NaN  NaN
# 9                CLAUDIA GALVAN   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 10                          CASA    1  NaN    3    3    2  NaN  NaN  NaN  NaN
# ...

# %%
df1 = pd.read_excel('Basee_de_Leads.xlsx')
df1.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df1 = pd.read_excel('Basee_de_Leads.xlsx')
#       2 df1.head()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
#     487 elif engine and engine != io.engine:
#     488     raise ValueError(
# ...
